# %% [markdown]
# # The Sparks Foundation - Internship

# %% [markdown]
# Data Science and Business Analytics Internship

# %% [markdown]
# # TASK - 3

# %% [markdown]
# # EXLPORATORY DATA ANALYSIS - RETAIL

# %% [markdown]
# Task done by - Hrishikesh Pawar

# %% [markdown]
# Data Used in the following Task - https://bit.ly/3i4rbWl

# %% [markdown]
# In this following Data Analysis Project I worked on as a Business Manager to find out :
# 1) The weak areas where I can work to make more profit.
#
# 2) What all business problems I can derive by exploring the data.

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing data sets
df = pd.read_csv("C:/Users/hp/OneDrive/Desktop/Work/Data Science/Datasets/Spark Foundation/SampleSuperstore.csv")

# %%
# Reading the dataset (Top 5)
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Checking the null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# data discription
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# plotting correlation heatmap
ds = df.corr()
sns.heatmap(ds, xticklabels=ds.columns, yticklabels=ds.columns, annot=True, 
            cmap=sns.diverging_palette(310, 2, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
#plotting relation between categories (segment & profit, region & profit, shipmode & profit)
sns.catplot(x="Segment" , y="Profit", data=df, kind='bar',palette='tab10',ci=None)

# %%
sns.catplot(x="Region",y="Profit", data=df,kind='bar',palette='tab10',ci=None)

# %%
sns.catplot(x="Ship Mode",y="Profit", data=df, kind='bar',palette='tab10',ci=None)

# %%
profit = df.groupby(["State"])["Profit"].mean().sort_values().index
sns.catplot(y="State",x="Profit",data=df,kind='bar',ci=None, height=15, order=order)

# %% [markdown]
# From the above plot we can clearly see that the states of Ohio, Colorado, North Carolina, Tennessee, Pennsylvania, Texas, Illionis, Arizona, Oregon and Florida yeild Loss.

# %%
sns.catplot(x="Category",y="Profit", data=df, kind='bar',palette='tab10',ci=None)

# %% [markdown]
# Here we observe that the 'Technology' sector provides maximum profit to the company as compared to the less-profit making sectors 'Furniture' and 'Office Supplies Category'.

# %% [markdown]
# Now we'll see the profit making categories in different regions

# %%
#profits in categories in different regions
sns.catplot(x="Category",y="Profit", data=df, kind='bar',palette='tab10',ci=None, col="Region")

# %% [markdown]
# Here we can see the Technology Sector is maximum profit making sector in every region (South, West, Central, East)
#
# but in the central region we can see that Furniture is not profitable.

# %%
order= df.groupby(['State'])['State'].count().sort_values().index
plt.figure(figsize=(12,10))
sns.countplot(y='State',data=df, order=order, palette="crest")
# Out:
# <AxesSubplot:xlabel='count', ylabel='State'>

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# 1. The most number of customers are from the states of California, New York and Texas.
#
# 2. The states like Wyoming, West Virginia and North Dalota have minimal or no sales at all. Hence, these the sales in these        states need to be overlooked.
#
# 3. The 'Technology' sector is generating the maximum profit in every reigon therefore, the sales can be maximised in order to      get maximum profit. On the other hand the 'Furniture' sector hasn't generated a good amount of profit for the company.
#
# 4. Selling Furniture in the central region is loss making and least profitable in the East region among all regions.
#
# 5. As Furniture is loss making in the central region the profits among different region doesn't vary much.

# %% [markdown]
# ## THANK YOU

# %% [markdown]
# Done by - Hrishikesh Pawar
